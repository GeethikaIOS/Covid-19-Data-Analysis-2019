# %%
#import the librariers
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt

# %%
#import the dataset
dataset = pd.read_csv(r"C:\Users\Geethika Reddy\Desktop\covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %% [markdown]
# # df=dataset.drop(["Lat","Long"],axis=1,inplace=True)

# %%
dataset
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
aggregated=dataset.groupby("Country/Region").sum()
# Out:
# C:\Users\Geethika Reddy\AppData\Local\Temp\ipykernel_23456\115003653.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   aggregated=dataset.groupby("Country/Region").sum()

# %%
aggregated.head()
# Out:
#                     Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan     33.0000  65.0000        0        0        0        0        0
# Albania         41.1533  20.1683        0        0        0        0        0
# Algeria         28.0339   1.6596        0        0        0        0        0
# Andorra         42.5063   1.5218        0        0        0        0        0
# Angola         -11.2027  17.8739        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
aggregated.shape
# Out:
# (187, 102)

# %%
aggregated.loc["Angola"].plot()
aggregated.loc["Afghanistan"].plot()
aggregated.loc["India"].plot()
aggregated.loc["Algeria"].plot()
plt.legend()

# %%
aggregated.loc["China"][2:6].plot()
# Out:
# <Axes: >

# %%
aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
aggregated.loc["West Bank and Gaza"].diff().max()
# Out:
# 66.0

# %%
aggregated
# Out:
#                           Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan         33.000000  65.000000        0        0        0        0
# Albania             41.153300  20.168300        0        0        0        0
# Algeria             28.033900   1.659600        0        0        0        0
# Andorra             42.506300   1.521800        0        0        0        0
# Angola             -11.202700  17.873900        0        0        0        0
# ...                       ...        ...      ...      ...      ...      ...
# West Bank and Gaza  31.952200  35.233200        0        0        0        0
# Western Sahara      24.215500 -12.885800        0        0        0        0
# Yemen               15.552727  48.516388        0        0        0        0
# Zambia             -15.416700  28.283300        0        0        0        0
# Zimbabwe           -20.000000  30.000000        0        0        0        0
#
# ...

# %%
countries=list(aggregated.index)
max_infected_counts=[]
for c in countries:
       max_infected_counts.append(aggregated.loc[c].diff().max())
aggregated["max_infected_counts"]=max_infected_counts

# %%
aggregated
# Out:
#                           Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan         33.000000  65.000000        0        0        0        0
# Albania             41.153300  20.168300        0        0        0        0
# Algeria             28.033900   1.659600        0        0        0        0
# Andorra             42.506300   1.521800        0        0        0        0
# Angola             -11.202700  17.873900        0        0        0        0
# ...                       ...        ...      ...      ...      ...      ...
# West Bank and Gaza  31.952200  35.233200        0        0        0        0
# Western Sahara      24.215500 -12.885800        0        0        0        0
# Yemen               15.552727  48.516388        0        0        0        0
# Zambia             -15.416700  28.283300        0        0        0        0
# Zimbabwe           -20.000000  30.000000        0        0        0        0
#
# ...

# %%
corana_data=pd.DataFrame(aggregated["max_infected_counts"])

# %%
corana_data
# Out:
#                     max_infected_counts
# Country/Region
# Afghanistan                  232.000000
# Albania                       34.000000
# Algeria                      199.000000
# Andorra                       43.000000
# Angola                        29.076600
# ...                                 ...
# West Bank and Gaza            66.000000
# Western Sahara                12.885800
# Yemen                         32.963661
# Zambia                        43.700000
# Zimbabwe                      50.000000
#
# [187 rows x 1 columns]

# %%
happy_report=pd.read_csv(r"C:\Users\Geethika Reddy\Desktop\worldwide_happiness_report.csv")

# %%
happy_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
useless_cols=["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happy_report.drop(useless_cols,axis=1,inplace=True)

# %%
happy_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happy_report.set_index("Country or region",inplace=True)

# %%
happy_report
# Out:
#                           GDP per capita  Social support  \
# Country or region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country or region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %%
corana_data.shape
# Out:
# (187, 1)

# %%
happy_report.shape
# Out:
# (156, 4)

# %%
data=corana_data.join(happy_report,how ="inner")

# %%
data
# Out:
#              max_infected_counts  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data.corr()
# Out:
#                               max_infected_counts  GDP per capita  \
# max_infected_counts                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infected_counts                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infected_counts                               0.078196
# ...

# %%
x=data["GDP per capita"]
y=data["max_infected_counts"]
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infected_counts'>

# %%
x=data["GDP per capita"]
y=data["max_infected_counts"]
x_log=np.log(x)
y_log=np.log(y)
sns.scatterplot(x=x,y=y_log)
# Out:
# C:\Users\Geethika Reddy\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='GDP per capita', ylabel='max_infected_counts'>

# %%
sns.regplot(x=x,y=y_log)
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infected_counts'>

# %%
x=data["Social support"]
y=data["max_infected_counts"]
x_log=np.log(x)
y_log=np.log(y)
sns.scatterplot(x=x,y=y_log)
# Out:
# C:\Users\Geethika Reddy\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='Social support', ylabel='max_infected_counts'>

# %%
sns.regplot(x=x,y=y)
# Out:
# <Axes: xlabel='Social support', ylabel='max_infected_counts'>

# %%
x=data["Healthy life expectancy"]
y=data["max_infected_counts"]
x_log=np.log(x)
y_log=np.log(y)
sns.scatterplot(x=x,y=y_log)
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infected_counts'>

# %%
sns.regplot(x=x,y=y_log)
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infected_counts'>
